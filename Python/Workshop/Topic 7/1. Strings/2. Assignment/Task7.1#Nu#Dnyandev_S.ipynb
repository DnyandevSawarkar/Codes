# %% [markdown]
# ### ASSIGNMENT 1 (3 MARKS)
# Write all the codes explain in a video provided in resource file.(Refer first video link for writing assignment 1)

# %%
#code 1
Course = "Python Programming"                     # Taking input string from user
print(len(Course))                                # printing length of string


#code2
print(Course[0])                                  # printing specific character
print(Course[-1])                                 # printing specific character


#code3
print(Course[0:3])                                # slicing the string


#code4
print(Course[0:])                                 # slicing the string


#code5
print(Course[:3])                                 # slicing the string

#code6
print(Course[:])                                  # slicing the string

#code7
Course = "Python \"Programming"                   # escape character
print(Course)

#code8
Course = "Python \'Programming"                   # escape character
print(Course)

#code9
Course = "Python \\Programming"                   # escape character
print(Course)

#code10
Course = "Python \nProgramming"                   # escape character
print(Course)


#code11
first ="Mosh"                                     # taking first string from user
last ="Hamedani"                                  # taking second string from user
full= first+" "+last                              # merging strings 
print(full)

#code12
full=f"{first} {last}"                            # merging strings
print(full)

#code13
full=f"{len(first)} {last}"    
print(full)

#Code14
full=f"{len(first)} {2+2}"
print(full)


#code15
Course = "Python Programming"                     # taking string from user
print(Course.upper())                             # converting character to upper case
print(Course)

#code16
print(Course.lower())                             # converting character to lower case

#code17
Course = "python programming"                     # taking string from user
print(Course.title())                             # converting first character to upper case

#code18
Course = "      python   programming        "     # taking string from user
print(Course.strip())                             # removing white spaces
print(Course.lstrip())                            # removing white spaces
print(Course.rstrip())                            # removing white spaces

#code19
print(Course.find("pro"))                         # finding index
print(Course.find("abc"))

#code20
print(Course.replace("p","j"))                    # replacing character from string

#code21
print("pro" in Course)                            # searching character in string

#code22
print("swift" not in Course)                      # searching character in string

# %% [markdown]
# ### ASSIGNMENT 2 (5 MARKS)
# Find length and count no. of r in a given string PERFORMER.

# %%
'''
this code help us to find length and count no of letter wanted of inputed string 
'''
string = str(input("Enter the string :"))                                                # string function used to stord the value of inputed string
count_no = input("Enter the Latter to count its number :")                               # count_no is used to get input of letter to find its count
print('Length of string :',len(string),'\nCount of',count_no,":",string.count(count_no)) # output of lenght string and count number of letter wanted

# %% [markdown]
# ### ASSIGNMENT 3 (7 MARKS)
#
# Code is given . Find out the errors and do the correction to get required Output.
#
# #### NOTE:   You can change the given string. But the string must be same for every case.
#
# OUTPUT:-
# 1. Length of your string should be 11.
# 2. Convert string to uppercase
# 3. Get 1th word of your using negative indexing
# 4. Range to get second word from your string
# 5. Split the string
# 6. Replace any word from your string with word 'Capstone-course'

# %%
s='6th hokage '
print('string :',s)

# length should be 11
print('length of s :', len(s))

# Convert everything to uppercase
print("S in uppercase :", s.upper())

# getting 1th word using negative indexing
print('1th char. from string is :', s[-11])

# what is the range to get second word from your string 
print('range to get 2nd word from string are :' , s[1:2])

# split the string
print('after spliting string is :',s.split())

# Replace
print('After replacing :',s.replace('hokage','Capstone-course'))
